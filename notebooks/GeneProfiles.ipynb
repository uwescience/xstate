# %% [markdown]
# # Gene Profiles

# %% [markdown]
# # Preliminaries

# %% [markdown]
# ## Imports

# %%
import init
from common import constants as cn
from tools import make_classification_data
from common.trinary_data import TrinaryData
from common import sample_data

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
data = make_classification_data.ClassificationData()
data.get(globals())

# %% [markdown]
# ## Constants

# %%
STAGES = list(cn.STATE_NAMES)
STAGES.remove("Normoxia")

# %% [markdown]
# # Profiles of SVM Weights

# %%
for key, clf in CLASSIFIER_DCT.items():
    print(", ".join(key))
    clf.plotSVMProfile()
# Out:
# T0, mycobactin
# T0, bacterioferritin
# T0, mycobactin_bacterioferritin
# T0, all
# pooled, mycobactin
# pooled, bacterioferritin
# pooled, mycobactin_bacterioferritin
# pooled, all

# %% [markdown]
# # Profiles of Feature Values Time SVM Weights

# %%
for key, clf in CLASSIFIER_DCT.items():
    ref, group = key
    # FIXME -- must calculate class averages
    if ref == "T0":
        trinary = TrinaryData(is_stage_averaged=True)
        print(", ".join(key))
        clf.plotSVMProfile(df_class=trinary.indexToInt())
# Out:
# T0, mycobactin
# T0, bacterioferritin
# T0, mycobactin_bacterioferritin
# T0, all

# %% [markdown]
# **Notes**
# 1. The absence of large negative weights in transition means that correct transition classification depends on gene *under-expression*.
